# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pydataset import data

# %% [markdown]
# ## Use the iris database to answer the following quesitons:

# %%
iris = data('iris')
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# ...

# %%
data('iris', show_doc = True)
# Out:
# iris
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Edgar Anderson's Iris Data
#
# ### Description
#
# This famous (Fisher's or Anderson's) iris data set gives the measurements in
# centimeters of the variables sepal length and width and petal length and
# width, respectively, for 50 flowers from each of 3 species of iris. The
# species are _Iris setosa_, _versicolor_, and _virginica_.
#
# ### Usage
#
#     iris
#     iris3
#
# ### Format
#
# `iris` is a data frame with 150 cases (rows) and 5 variables (columns) named
# `Sepal.Length`, `Sepal.Width`, `Petal.Length`, `Petal.Width`, and `Species`.
#
# `iris3` gives the same data arranged as a 3-dimensional array of size 50 by 4
# by 3, as represented by S-PLUS. The first dimension gives the case number
# within the species subsample, the second the measurements with names `Sepal
# L.`, `Sepal W.`, `Petal L.`, and `Petal W.`, and the third the species.
#
# ### Source
#
# ...

# %% [markdown]
# ### What does the distribution of petal lengths look like?

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
iris.rename(columns = {'Sepal.Length': 'Sepal_Length','Sepal.Width':'Sepal_Width', 'Petal.Length': 'Petal_Length', 'Petal.Width':'Petal_Width'}, inplace = True)
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
sns.displot(data = iris.Petal_Length, kde = True)

# %% [markdown]
# ### Is there a correlation between petal length and petal width?

# %%
iris.corr()
#see map below--the correlation is .96
# Out:
#               Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# Sepal_Length      1.000000    -0.117570      0.871754     0.817941
# Sepal_Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal_Length      0.871754    -0.428440      1.000000     0.962865
# Petal_Width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), cmap = 'RdBu_r',   #as taken from today's lesson
           center = 0,
#            vmax = 1,
#            vmin = -1,
            annot = True,
#             fmt = '.2f',
#             linewidth = 1,
#             linecolor = 'k',
#             xticklabels = labels,
#             yticklabels = labels
           )
# Out:
# <AxesSubplot:>

# %%
#ravinder's solution:
sns.relplot(data = iris, x = 'Petal_Length', y = 'Petal_Width', hue = 'Species')
#like what i did below...

# %% [markdown]
# ### Would it be reasonable to predict species based on sepal width and sepal length?

# %%
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot(data = iris, x = 'Sepal_Width', y = 'Sepal_Length',
            hue = 'Species',
#            style = 'nnnnnn',
#            size = 'nnnnnnn'
           )
#more or less, yes. Especially Setosa; the versicolor and virginica ar more mixed in together

# %%
sns.relplot(data = iris, x = 'Sepal_Length', y = 'Sepal_Width', hue = 'Species')

#ravinder:

# %% [markdown]
# ### Which features would be best used to predict species?

# %%
sns.relplot(data = iris, x = 'Petal_Width', y = 'Petal_Length',
            hue = 'Species',
#            style = 'nnnnnn',
#            size = 'nnnnnnn'
           )

#much stronger-looking correlation

# %%
#ravinder:
sns.pairplot(data = iris, hue = 'Species')
#gives a quick overview to get an idea what's good for the question

# %%
sns.boxplot(y = "Petal_Length", x = 'Species', data = iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Petal_Length'>

# %% [markdown]
# ## Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set.

# %%
anscombe = sns.load_dataset('anscombe')
anscombe.sample(5)
# Out:
#    dataset     x     y
# 42      IV   8.0  7.91
# 14      II   9.0  8.77
# 19      II  12.0  9.13
# 11      II  10.0  9.14
# 10       I   5.0  5.68

# %%
anscombe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
anscombe.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %% [markdown]
# ### Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?

# %%
anscombe.groupby('dataset').describe()
#i'm noticing the same mean across 'datasets' (differing from x to y), yet different std, etc.
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %% [markdown]
# ### Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
#sns.barplot(data = anscombe, x = 'dataset', y = 'y') #, hue = 'dataset')
# sns.barplot(data = tips, x = 'sex', y = 'tip', hue = 'time')

#not getting what i need here. not even sure what i need

sns.relplot(data = anscombe, x = 'x', y = 'y', col = 'dataset') #, hue = 'dataset')

#ok now i see.

# %%
sns.lmplot(data = anscombe, x = 'x', y = 'y', col = 'dataset')

# %% [markdown]
# ### Load the InsectSprays dataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
Insect_Sprays = data('InsectSprays')
Insect_Sprays.sample(5)
#spray is the categorical, count is the numerical
# Out:
#     count spray
# 62      9     F
# 29      3     C
# 41      4     D
# 38      5     D
# 53      3     E

# %%
#sns.boxplot(data = Insect_Sprays)
plt.figure(figsize=(8,6))
sns.boxplot(data = Insect_Sprays, y = 'count', x = 'spray')
plt.title("Comparing Efficacy of Insect Sprays")
#c, d, and e are more effective bc they produce a lower bug count after application
# Out:
# Text(0.5, 1.0, 'Comparing Efficacy of Insect Sprays')

# %% [markdown]
# ### Load the swiss dataset and read it's documentation. The swiss dataset is available from pydatset rather than seaborn. Create visualizations to answer the following questions:

# %%
swiss = data('swiss')
swiss.sample(5)
# Out:
#             Fertility  Agriculture  Examination  Education  Catholic  \
# Avenches         68.9         60.7           19         12      4.43
# Le Locle         72.7         16.7           22         13     11.22
# Sierre           92.2         84.6            3          3     99.46
# Morges           65.5         59.8           22         10      5.23
# Val de Ruz       77.6         37.6           15          7      4.97
#
#             Infant.Mortality
# Avenches                22.7
# Le Locle                18.9
# Sierre                  16.3
# Morges                  18.0
# Val de Ruz              20.0

# %%
swiss.index.name = 'Province'
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Province
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Province
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %% [markdown]
# ### Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
swiss['is_catholic'] = np.where(swiss.Catholic >= 60, True, False)
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# Moutier                   20.3        False
# Neuveville                20.6        False

# %%
plt.hist(swiss.Catholic)
# Out:
# (array([21.,  5.,  1.,  1.,  2.,  1.,  0.,  0.,  1., 15.]),
#  array([  2.15 ,  11.935,  21.72 ,  31.505,  41.29 ,  51.075,  60.86 ,
#          70.645,  80.43 ,  90.215, 100.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Does whether or not a province is Catholic influence fertility?

# %%
sns.scatterplot(data = swiss, x = 'Catholic', y = 'Fertility', hue = 'is_catholic')
# Out:
# <AxesSubplot:xlabel='Catholic', ylabel='Fertility'>

# %%
sns.barplot(data = swiss, x = 'is_catholic', y = 'Fertility')
# Out:
# <AxesSubplot:xlabel='is_catholic', ylabel='Fertility'>

# %%
sns.boxplot(x = 'is_catholic', y = 'Fertility', data = swiss)
# Out:
# <AxesSubplot:xlabel='is_catholic', ylabel='Fertility'>

# %% [markdown]
# ### What measure correlates most strongly with fertility?

# %%
swiss.corr().Fertility
#CHECK IT OUT: YOU CAN DO IT JUST FOR FERTILITY
#looks like education is actually slightly more correlated with fertility, with is_catholic second
# Out:
# Fertility           1.000000
# Agriculture         0.353079
# Examination        -0.645883
# Education          -0.663789
# Catholic            0.463685
# Infant.Mortality    0.416556
# is_catholic         0.605023
# Name: Fertility, dtype: float64

# %%
sns.heatmap(swiss.corr(), cmap = 'RdBu_r',   #vs 'RdBu'
           center = 0,
           vmax = 1,
           vmin = -1,
            annot = True,
            fmt = '.2f',
            linewidth = 1,
            linecolor = 'k',
            #xticklabels = labels,
            #yticklabels = labels
           )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Using the chipotle dataset from the previous exercise, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
from get_db_url import get_db_url
url = get_db_url('chipotle')
sql = """
    SELECT * from orders
"""
chipotle_df = pd.read_sql(sql,url)
chipotle_df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
chipotle_df['item_price'] = chipotle_df.item_price.apply(lambda value : float(value[1:].strip()))
# i ran the above code to get those item_price strings into float format
chipotle_df.sample()
# Out:
#         id  order_id  quantity          item_name choice_description  \
# 4480  4481      1785         1  Canned Soft Drink        [Diet Coke]
#
#       item_price
# 4480        1.25

# %%
most_popular = chipotle_df.pivot_table(aggfunc='sum', index='item_name').reset_index().sort_values(by='quantity', ascending = False).head(4)
most_popular
#practice not returning all the extraneous columns
# Out:
#               item_name       id  item_price  order_id  quantity
# 17         Chicken Bowl  1780635     7342.73    713926       761
# 18      Chicken Burrito  1238770     5575.82    497303       591
# 25  Chips and Guacamole  1122252     2201.04    449959       506
# 39        Steak Burrito   818163     3851.43    328437       386

# %%
most_popular.index
# Out:
# Int64Index([17, 18, 25, 39], dtype='int64')

# %%
sns.barplot(data = most_popular, x = 'item_name', y = 'item_price')
plt.xlabel("Item", )
plt.ylabel("Revenue")
plt.tight_layout()

# %% [markdown]
# ### Load the sleepstudy data and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
sleepstudy = data('sleepstudy')
sleepstudy
# Out:
#      Reaction  Days  Subject
# 1    249.5600     0      308
# 2    258.7047     1      308
# 3    250.8006     2      308
# 4    321.4398     3      308
# 5    356.8519     4      308
# ..        ...   ...      ...
# 176  329.6076     5      372
# 177  334.4818     6      372
# 178  343.2199     7      372
# 179  369.1417     8      372
# 180  364.1236     9      372
#
# [180 rows x 3 columns]

# %%
sleepstudy['Subject'] = 'subject_' + sleepstudy['Subject'].astype(str)

# %%
plt.figure(figsize = (16,9))
sns.lineplot(data = sleepstudy, x = 'Days', y = 'Reaction', hue = 'Subject') #, color = 'RdBu_r')
sns.lineplot(data = sleepstudy, x = 'Days', y = 'Reaction', color = 'b')
sns.color_palette("crest", as_cmap=True)
#don't forget the way to put two plots on one graph : ))

# %%
sns.relplot(data = sleepstudy, x = 'Days', y = 'Reaction', kind = 'line')
