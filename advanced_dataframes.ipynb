# %%
import pandas as pd
from pydataset import data
import matplotlib as plt
import numpy as np

# %%
from get_db_url import get_db_url

# %% [markdown]
# # Exercises I

# %% [markdown]
# ### 1. Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)

# %% [markdown]
# ### 2. cd into your exercises folder for this module and run echo env.py >> .gitignore

# %% [markdown]
# ### 3. Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
#see above code, i imported from file

# %% [markdown]
# ### 4. Use your function to obtain a connection to the employees database.

# %%
sql = """
    SELECT * from departments limit 3000
"""

# %%
url = get_db_url('employees')
departments_df = pd.read_sql(sql,url)
departments_df.head()
# Out:
#   dept_no         dept_name
# 0    d009  Customer Service
# 1    d005       Development
# 2    d002           Finance
# 3    d003   Human Resources
# 4    d001         Marketing

# %% [markdown]
# ### 5. Once you have successfully run a query:
#
# a. Intentionally make a typo in the database url. What kind of error message do you see?
#
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
#done

# %% [markdown]
# ### 6. Read the employees and titles tables into two separate DataFrames.

# %%
sql = """
    SELECT * from employees
"""

# %%
url = get_db_url('employees')
df_employees = pd.read_sql(sql,url)
df_employees.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
sql = """
    SELECT * from titles WHERE to_date < '9999-01-01'
"""

# %%
url = get_db_url('employees')
df_titles = pd.read_sql(sql,url)
df_titles.head()
# Out:
#    emp_no               title   from_date     to_date
# 0   10004            Engineer  1986-12-01  1995-12-01
# 1   10005               Staff  1989-09-12  1996-09-12
# 2   10007               Staff  1989-02-10  1996-02-11
# 3   10008  Assistant Engineer  1998-03-11  2000-07-31
# 4   10009  Assistant Engineer  1985-02-18  1990-02-18

# %% [markdown]
# ### 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
df_titles = pd.DataFrame(df_titles)
df_titles
# Out:
#         emp_no               title   from_date     to_date
# 0        10004            Engineer  1986-12-01  1995-12-01
# 1        10005               Staff  1989-09-12  1996-09-12
# 2        10007               Staff  1989-02-10  1996-02-11
# 3        10008  Assistant Engineer  1998-03-11  2000-07-31
# 4        10009  Assistant Engineer  1985-02-18  1990-02-18
# ...        ...                 ...         ...         ...
# 203179  499992               Staff  1987-05-10  1992-05-09
# 203180  499994            Engineer  1993-02-22  1993-10-27
# 203181  499996            Engineer  1996-05-13  2002-05-13
# 203182  499997            Engineer  1987-08-30  1992-08-29
# 203183  499998               Staff  1993-12-27  1998-12-27
#
# [203184 rows x 4 columns]

# %%
df_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203184 entries, 0 to 203183
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     203184 non-null  int64
#  1   title      203184 non-null  object
#  2   from_date  203184 non-null  object
#  3   to_date    203184 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 6.2+ MB

# %%
df_employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
df_titles.shape
# Out:
# (203184, 4)

# %%
df_employees.shape
# Out:
# (300024, 6)

# %% [markdown]
# ### 8. Display the summary statistics for each DataFrame.

# %%
df_titles.describe()
# Out:
#               emp_no
# count  203184.000000
# mean   253068.438849
# std    161853.933271
# min     10004.000000
# 25%     84833.750000
# 50%    249902.000000
# 75%    424885.250000
# max    499998.000000

# %%
df_employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %% [markdown]
# ### 9. How many unique titles are in the titles DataFrame?

# %%
len(df_titles['title'].unique())
# Out:
# 7

# %% [markdown]
# ### 10. What is the oldest date in the to_date column?

# %%
df_titles.to_date.sort_values().head()
# Out:
# 7303      1985-03-01
# 186225    1985-03-11
# 158686    1985-03-20
# 16209     1985-03-23
# 127199    1985-04-17
# Name: to_date, dtype: object

# %% [markdown]
# ### 11. What is the most recent date in the to_date column?

# %%
df_titles[(df_titles.to_date.astype(str) < '9999-01-01')].max()
# Out:
# emp_no                 499998
# title        Technique Leader
# from_date          2002-06-30
# to_date            2002-08-01
# dtype: object

# %%
#if we want to solve this changing the to_dates to a date format....
df_titles.from_date = pd.to_datetime(df_titles.from_date)
df_titles.to_date = pd.to_datetime(df_titles.to_date)
df_titles.dtypes
#not working b/c ????
# Out:
# emp_no                int64
# title                object
# from_date    datetime64[ns]
# to_date      datetime64[ns]
# dtype: object

# %% [markdown]
# # Exercises II
#
# ### 1. Copy the users and roles DataFrames from the examples above.

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# ### 2. What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, how='right', on=None, left_on=None, right_on=None, left_index=False, right_index=False, indicator=False)
# Out:
#    id       name  role_id
# 0   1      admin      NaN
# 1   2     author      NaN
# 2   3   reviewer      NaN
# 3   4  commenter      NaN

# %% [markdown]
# ### 3. What is the result of using an outer join on the DataFrames?

# %%
#users.merge(roles, how='outer', on=None, left_on=None, right_on=None, left_index=False, right_index=False, indicator=False)
users.merge(roles, how='outer')
# Out:
#    id       name  role_id
# 0   1        bob      1.0
# 1   2        joe      2.0
# 2   3      sally      3.0
# 3   4       adam      3.0
# 4   5       jane      NaN
# 5   6       mike      NaN
# 6   1      admin      NaN
# 7   2     author      NaN
# 8   3   reviewer      NaN
# 9   4  commenter      NaN

# %%
pd.merge(users,roles,left_on='role_id',right_on='id',how='outer')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %% [markdown]
# ### 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users.drop(['role_id'], axis = 1, inplace = True)
users
# Out:
#    id   name
# 0   1    bob
# 1   2    joe
# 2   3  sally
# 3   4   adam
# 4   5   jane
# 5   6   mike

# %%
users.merge(roles)
# Out:
# Empty DataFrame
# Columns: [id, name]
# Index: []

# %% [markdown]
# ### 5. Load the mpg dataset from PyDataset.
#
# ### 6. Output and read the documentation for the mpg dataset.

# %%
mpg = data('mpg')
data('mpg', show_doc = True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# ### 7. How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# ### 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg.rename(columns={'cty':'city', 'hwy': 'highway', 'class': 'car_class'}, inplace = True)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     car_class
# 1     compact
# ...

# %% [markdown]
# ### 9. Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#             displ         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   city          234 non-null    int64
#  8   highway       234 non-null    int64
#  9   fl            234 non-null    object
#  10  car_class     234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# ### 10. How many different manufacturers are there?

# %%
len(mpg['manufacturer'].unique())
# Out:
# 15

# %% [markdown]
# ### 11. How many different models are there?

# %%
mpg.model.value_counts().sum()
# Out:
# 234

# %% [markdown]
# ### 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#   car_class  mileage_difference
# 1   compact                  11
# 2   compact                   8
# 3   compact                  11
# 4   compact                   9
# 5   compact                  10

# %% [markdown]
# ### 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = ((mpg.highway + mpg.city) / 2)
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#   car_class  mileage_difference  average_mileage
# 1   compact                  11             23.5
# 2   compact                   8             25.0
# 3   compact                  11             25.5
# 4   compact                   9             25.5
# 5   compact                  10             21.0

# %% [markdown]
# ### 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = mpg.trans.str.startswith('auto')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#   car_class  mileage_difference  average_mileage  is_automatic
# 1   compact                  11             23.5          True
# 2   compact                   8             25.0         False
# 3   compact                  11             25.5         False
# 4   compact                   9             25.5          True
# 5   compact                  10             21.0          True

# %%
#see john's lambda function here!

# %% [markdown]
# ### 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby(['manufacturer']).average_mileage.agg(['mean']).sort_values(by = 'mean').tail()
# Out:
#                    mean
# manufacturer
# audi          22.027778
# subaru        22.428571
# hyundai       22.750000
# volkswagen    25.074074
# honda         28.500000

# %%
mpg.groupby('manufacturer').average_mileage.agg('mean').sort_values().tail(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %% [markdown]
# ### 16. Do automatic or manual cars have better miles per gallon?

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#   car_class  mileage_difference  average_mileage  is_automatic
# 1   compact                  11             23.5          True
# 2   compact                   8             25.0         False
# 3   compact                  11             25.5         False
# 4   compact                   9             25.5          True
# 5   compact                  10             21.0          True

# %%
mpg[mpg.is_automatic == True]
# Out:
#     manufacturer                   model  displ  year  cyl     trans drv  \
# 1           audi                      a4    1.8  1999    4  auto(l5)   f
# 4           audi                      a4    2.0  2008    4  auto(av)   f
# 5           audi                      a4    2.8  1999    6  auto(l5)   f
# 7           audi                      a4    3.1  2008    6  auto(av)   f
# 9           audi              a4 quattro    1.8  1999    4  auto(l5)   4
# 11          audi              a4 quattro    2.0  2008    4  auto(s6)   4
# 12          audi              a4 quattro    2.8  1999    6  auto(l5)   4
# 14          audi              a4 quattro    3.1  2008    6  auto(s6)   4
# 16          audi              a6 quattro    2.8  1999    6  auto(l5)   4
# 17          audi              a6 quattro    3.1  2008    6  auto(s6)   4
# 18          audi              a6 quattro    4.2  2008    8  auto(s6)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8  auto(l4)   r
# ...

# %%
mpg.groupby(['is_automatic']).agg(['mean'])
#I think this is my answer : )
# Out:
#                  displ         year       cyl       city    highway  \
#                   mean         mean      mean       mean       mean
# is_automatic
# False         2.966234  2002.974026  5.246753  18.675325  25.779221
# True          3.719745  2003.757962  6.203822  15.968153  22.292994
#
#              mileage_difference average_mileage
#                            mean            mean
# is_automatic
# False                  7.103896       22.227273
# True                   6.324841       19.130573

# %% [markdown]
# # EXERCISES III

# %% [markdown]
# ### 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
from get_db_url import get_db_url

# %%
url = get_db_url('chipotle')

# %%
sql = """
    SELECT * from orders
"""

# %%
chipotle_df = pd.read_sql(sql,url)
chipotle_df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %% [markdown]
# ### 2. What is the total price for each order?

# %%
chipotle_df.dtypes
#note that the price column is 'object' data type : (
# Out:
# id                     int64
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chipotle_df['numeric_price'] = chipotle_df['item_price'].str.replace('$',"")
chipotle_df.head()
# Out:
# <ipython-input-50-141c15e4ddf4>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   chipotle_df['numeric_price'] = chipotle_df['item_price'].str.replace('$',"")
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# ...

# %%
chipotle_df['item_price_final'] = chipotle_df['numeric_price'].astype(float)
chipotle_df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price numeric_price  item_price_final
# 0     $2.39          2.39               2.39
# ...

# %%
chipotle_df.groupby(['order_id']).agg(['sum'])
#is there a datatype problem with the item_price column? yes. see above cells to fix it
#this is your answer btw
# Out:
#              id quantity  \
#             sum      sum
# order_id
# 1            10        4
# 2             5        2
# 3            13        2
# 4            17        2
# 5            21        2
# ...         ...      ...
# 1830       9223        2
# 1831      13842        3
# 1832       9233        2
# 1833       9237        2
# 1834      13863        3
#
#                                                                                       item_name  \
#                                                                                             sum
# order_id
# 1         Chips and Fresh Tomato SalsaIzzeNantucket NectarChips and Tomatillo-Green Chili Salsa
# 2                                                                                  Chicken Bowl
# 3                                                                     Chicken BowlSide of Chips
# 4                                                                 Steak BurritoSteak Soft Tacos
# ...

# %%
chipotle_df['item_price'] = chipotle_df.item_price.apply(lambda value : float(value[1:].strip()))
chipotle_df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price numeric_price  item_price_final
# 0        2.39         2.39               2.39
# ...

# %%
chipotle_df.info()
#now it's a float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   float64
#  6   numeric_price       4622 non-null   object
#  7   item_price_final    4622 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 289.0+ KB

# %% [markdown]
# ### 3. What are the most popular 3 items?

# %%
chipotle_df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price numeric_price  item_price_final
# 0        2.39         2.39               2.39
# ...

# %%
chipotle_df.pivot_table(aggfunc='sum', index='item_name').reset_index().sort_values(by='quantity', ascending = False).head(3)
#see how the `.reset_index()` function helped you here.  otherwise it returns an error
# Out:
#               item_name       id  item_price  item_price_final  order_id  \
# 17         Chicken Bowl  1780635     7342.73           7342.73    713926
# 18      Chicken Burrito  1238770     5575.82           5575.82    497303
# 25  Chips and Guacamole  1122252     2201.04           2201.04    449959
#
#     quantity
# 17       761
# 18       591
# 25       506

# %%
chipotle_df.groupby('item_name').quantity.agg('sum').sort_values(ascending=False).head(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %%
pd.crosstab(chipotle_df.item_name, chipotle_df.quantity.sum())
#joann's excellent solution
# Out:
# col_0                                  4972
# item_name
# 6 Pack Soft Drink                        54
# Barbacoa Bowl                            66
# Barbacoa Burrito                         91
# Barbacoa Crispy Tacos                    11
# Barbacoa Salad Bowl                      10
# Barbacoa Soft Tacos                      25
# Bottled Water                           162
# Bowl                                      2
# Burrito                                   6
# Canned Soda                             104
# Canned Soft Drink                       301
# Carnitas Bowl                            68
# Carnitas Burrito                         59
# Carnitas Crispy Tacos                     7
# Carnitas Salad                            1
# Carnitas Salad Bowl                       6
# Carnitas Soft Tacos                      40
# Chicken Bowl                            726
# Chicken Burrito                         553
# Chicken Crispy Tacos                     47
# ...

# %%
num_item_ordered = chipotle_df.groupby('item_name').quantity.agg(['sum'])
num_item_ordered.nlargest(3, 'sum')
# Out:
#                      sum
# item_name
# Chicken Bowl         761
# Chicken Burrito      591
# Chips and Guacamole  506

# %%
mpg.groupby(['manufacturer']).average_mileage.agg(['mean']).sort_values(by = 'mean').tail()
# Out:
#                    mean
# manufacturer
# audi          22.027778
# subaru        22.428571
# hyundai       22.750000
# volkswagen    25.074074
# honda         28.500000

# %%
# chipotle_df.pivot_table(aggfunc='sum', index='item_name')
# chipotle_df.groupby('item_name').quantity.agg(['sum']) ....and then sort.head
#oh, turns out Joann didn't have to make a crosstab at all, so that wasn't so excellent after all.

# %% [markdown]
# ### 4. Which item has produced the most revenue?

# %%
chipotle_df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price numeric_price  item_price_final
# 0        2.39         2.39               2.39
# ...

# %%
chipotle_df.pivot_table(aggfunc='sum', index='item_name').reset_index().sort_values(by='item_price_final', ascending = False).head(3)
#all set
# Out:
#           item_name       id  item_price  item_price_final  order_id  quantity
# 17     Chicken Bowl  1780635     7342.73           7342.73    713926       761
# 18  Chicken Burrito  1238770     5575.82           5575.82    497303       591
# 39    Steak Burrito   818163     3851.43           3851.43    328437       386

# %%
revenue = chipotle_df.groupby('item_name').item_price_final.agg(['sum'])
revenue.nlargest(3, 'sum')
# Out:
#                      sum
# item_name
# Chicken Bowl     7342.73
# Chicken Burrito  5575.82
# Steak Burrito    3851.43

# %%
#sort_values.head()

# %% [markdown]
# ### 5. Join the employees and titles DataFrames together.

# %%
df_employees.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
df_titles.head()
# Out:
#    emp_no               title  from_date    to_date
# 0   10004            Engineer 1986-12-01 1995-12-01
# 1   10005               Staff 1989-09-12 1996-09-12
# 2   10007               Staff 1989-02-10 1996-02-11
# 3   10008  Assistant Engineer 1998-03-11 2000-07-31
# 4   10009  Assistant Engineer 1985-02-18 1990-02-18

# %%
df_employees.merge(df_titles, how='inner')
# Out:
#         emp_no  birth_date first_name  last_name gender   hire_date  \
# 0        10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 1        10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 2        10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 3        10008  1958-02-19     Saniya   Kalloufi      M  1994-09-15
# 4        10009  1952-04-19     Sumant       Peac      F  1985-02-18
# ...        ...         ...        ...        ...    ...         ...
# 203179  499992  1960-10-12     Siamak   Salverda      F  1987-05-10
# 203180  499994  1952-02-26      Navin    Argence      F  1990-04-24
# 203181  499996  1953-03-07       Zito       Baaz      M  1990-09-27
# 203182  499997  1961-08-03    Berhard     Lenart      M  1986-04-21
# 203183  499998  1956-09-05   Patricia    Breugel      M  1993-10-13
#
#                      title  from_date    to_date
# 0                 Engineer 1986-12-01 1995-12-01
# 1                    Staff 1989-09-12 1996-09-12
# ...

# %%
employee_titles = pd.merge(df_employees, df_titles, left_on='emp_no',right_on='emp_no', how='inner')
employee_titles
# Out:
#         emp_no  birth_date first_name  last_name gender   hire_date  \
# 0        10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 1        10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 2        10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 3        10008  1958-02-19     Saniya   Kalloufi      M  1994-09-15
# 4        10009  1952-04-19     Sumant       Peac      F  1985-02-18
# ...        ...         ...        ...        ...    ...         ...
# 203179  499992  1960-10-12     Siamak   Salverda      F  1987-05-10
# 203180  499994  1952-02-26      Navin    Argence      F  1990-04-24
# 203181  499996  1953-03-07       Zito       Baaz      M  1990-09-27
# 203182  499997  1961-08-03    Berhard     Lenart      M  1986-04-21
# 203183  499998  1956-09-05   Patricia    Breugel      M  1993-10-13
#
#                      title  from_date    to_date
# 0                 Engineer 1986-12-01 1995-12-01
# 1                    Staff 1989-09-12 1996-09-12
# ...

# %% [markdown]
# ### 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
df_employees.merge(df_titles, how='inner').groupby('title').hire_date.agg('max')
#hire_date not from_date
# Out:
# title
# Assistant Engineer    1999-11-16
# Engineer              2000-01-28
# Manager               1991-08-17
# Senior Engineer       1999-12-11
# Senior Staff          2000-01-08
# Staff                 2000-01-02
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %%
employee_titles.groupby('title').hire_date.agg('max')
# Out:
# title
# Assistant Engineer    1999-11-16
# Engineer              2000-01-28
# Manager               1991-08-17
# Senior Engineer       1999-12-11
# Senior Staff          2000-01-08
# Staff                 2000-01-02
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %% [markdown]
# ### 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
crossed_df = pd.read_sql('SELECT * FROM employees JOIN titles USING(emp_no) JOIN dept_emp USING(emp_no) JOIN departments USING(dept_no)', get_db_url('employees'))
crossed_df.head()
#joann's offering
#don't forget you can put your sql query right in the pd.read command
# Out:
#   dept_no  emp_no  birth_date first_name last_name gender   hire_date  \
# 0    d009   10011  1953-11-07       Mary     Sluis      F  1990-01-22
# 1    d009   10038  1960-07-20       Huan     Lortz      M  1989-09-20
# 2    d009   10038  1960-07-20       Huan     Lortz      M  1989-09-20
# 3    d009   10049  1961-04-24      Basil    Tramer      F  1992-05-04
# 4    d009   10049  1961-04-24      Basil    Tramer      F  1992-05-04
#
#           title   from_date     to_date   from_date     to_date  \
# 0         Staff  1990-01-22  1996-11-09  1990-01-22  1996-11-09
# 1  Senior Staff  1996-09-20  9999-01-01  1989-09-20  9999-01-01
# 2         Staff  1989-09-20  1996-09-20  1989-09-20  9999-01-01
# 3  Senior Staff  2000-05-04  9999-01-01  1992-05-04  9999-01-01
# 4         Staff  1992-05-04  2000-05-04  1992-05-04  9999-01-01
#
#           dept_name
# 0  Customer Service
# 1  Customer Service
# 2  Customer Service
# 3  Customer Service
# 4  Customer Service

# %%
pd.crosstab(crossed_df.dept_name,crossed_df.title).T
#i was close, but had to transpose it to get it right
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        6445                1831       378      0
# Engineer                    0       49649               13852      2986      0
# Manager                     2           4                   4         2      2
# ...

# %%
pd.crosstab(crossed_df.title,crossed_df.dept_name)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        6445                1831       378      0
# Engineer                    0       49649               13852      2986      0
# Manager                     2           4                   4         2      2
# ...
